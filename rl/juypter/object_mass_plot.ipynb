# %%
real_masses = [
  93.0,
  119.0,
  187.0,
  224.0,
  200.0,
  159.0,
  180.0,
  232.0,
  478.0,
  455.0,
  217.0,
  598.0,
  335.0,
  491.0,
  565,
  597.0,
  108.0,
  251,
  541.0,
  341.0,
  638.0,
  637.0,
  170.0,
  622.0,
  895.0,
]

ycb_masses = [
  27.0,
  33.0,
  31.0,
  20.0,
  51.0,
  55.0,
  66.0,
  43.0,
  37.0,
  68.0,
  23.0,
  48.0,
  8.0,
  23.0,
  13.0,
  24.0,
  45.0,
  65.0,
]

green_masses = [
  3,
  5,
  9,
  19,
  30,
  47,
  39,
  28,
  34,
  18,
  84,
  64,
  53,
  23,
  40,
  7,
  21,
  18,
  41,
  63,
  12,
  20,
  45,
  75,
  20,
  44,
  12,
  7,
  53,
  106,
]

# %%
sim_masses = [
  1000 * 0.203575204,
  1000 * 0.118141108,
  1000 * 0.189225,
  1000 * 0.022287905,
  1000 * 0.050646504,
  1000 * 0.1125,
  1000 * 0.074189214,
  1000 * 0.08635934,
  1000 * 0.061465592,
  1000 * 0.03092927,
  1000 * 0.127215955,
  1000 * 0.145885858,
  1000 * 0.036823288,
  1000 * 0.010140738,
  1000 * 0.139384629,
  1000 * 0.016457641,
  1000 * 0.136684354,
  1000 * 0.171766578,
  1000 * 0.058516056,
  1000 * 0.026939157,
  1000 * 0.1125,
  1000 * 0.189225,
  1000 * 0.118141108,
  1000 * 0.125727114,
  1000 * 0.325987407,
  1000 * 0.080374344,
  1000 * 0.036443149,
  1000 * 0.029679492,
  1000 * 0.109863281,
  1000 * 0.0882,
  1000 * 0.055544537,
  1000 * 0.005554487,
  1000 * 0.13635886,
  1000 * 0.0648,
  1000 * 0.016365906,
  1000 * 0.081111719,
  1000 * 0.125194299,
  1000 * 0.072111916,
  1000 * 0.197837905,
  1000 * 0.168454688,
  1000 * 0.104536496,
  1000 * 0.136115229,
  1000 * 0.025,
  1000 * 0.024540115,
  1000 * 0.028940625,
  1000 * 0.343533157,
  1000 * 0.1251005,
  1000 * 0.092719534,
  1000 * 0.092719534,
  1000 * 0.022287905,
  1000 * 0.146484375,
  1000 * 0.109232627,
  1000 * 0.0192,
  1000 * 0.192485742,
  1000 * 0.089672432,
  1000 * 0.060748602,
  1000 * 0.046132031,
  1000 * 0.050646504,
  1000 * 0.0128,
  1000 * 0.046132031,
  1000 * 0.075969755,
  1000 * 0.092264063,
  1000 * 0.060748602,
  1000 * 0.034741691,
  1000 * 0.075187172,
  1000 * 0.172551976,
  1000 * 0.0432,
  1000 * 0.049459476,
  1000 * 0.241212059,
  1000 * 0.016457641,
  1000 * 0.2109375,
  1000 * 0.007732317,
  1000 * 0.030422215,
  1000 * 0.025,
  1000 * 0.003414755,
  1000 * 0.234169822,
  1000 * 0.064303125,
  1000 * 0.052733161,
  1000 * 0.118141108,
  1000 * 0.038618252,
  1000 * 0.24215277,
  1000 * 0.034757227,
  1000 * 0.117958675,
  1000 * 0.017685949,
  1000 * 0.080374344,
  1000 * 0.008180038,
  1000 * 0.343533157,
  1000 * 0.072111916,
  1000 * 0.107756628,
  1000 * 0.15435,
  1000 * 0.072111916,
  1000 * 0.343533157,
  1000 * 0.064303125,
  1000 * 0.189225,
  1000 * 0.056543773,
  1000 * 0.1125,
  1000 * 0.129850061,
  1000 * 0.016457641,
  1000 * 0.109232627,
  1000 * 0.06259715,
]

# %%
import matplotlib.pyplot as plt
import numpy as np

# increase matplotlib resolution
plt.rcParams['figure.dpi'] = 600
plt.rcParams['savefig.dpi'] = 600

fig = [None for i in range(4)]
axs = [None for i in range(4)]

xsize = 1
ysize = 3

fig[0], axs[0] = plt.subplots(nrows=1, ncols=1, figsize=(xsize, ysize*1.2))
fig[1], axs[1] = plt.subplots(nrows=1, ncols=1, figsize=(xsize, ysize*1.2))
fig[2], axs[2] = plt.subplots(nrows=1, ncols=1, figsize=(xsize, ysize*0.7))
fig[3], axs[3] = plt.subplots(nrows=1, ncols=1, figsize=(xsize, ysize*0.7))

title = "Mass\nDistribution"

# plot violin plot
axs[0].violinplot(real_masses[:24],
                  showmeans=False,
                  showmedians=True)
axs[0].set_title(title)

# plot violin plot
axs[1].violinplot(ycb_masses,
                  showmeans=False,
                  showmedians=True)
axs[1].set_title(title)

# plot violin plot
axs[2].violinplot(green_masses,
                  showmeans=False,
                  showmedians=True)
axs[2].set_title(title)

# plot violin plot
axs[3].violinplot(sim_masses,
                  showmeans=False,
                  showmedians=True)
axs[3].set_title(title)

# adding horizontal grid lines
for ax in axs:
    ax.yaxis.grid(True)
    ax.set_xticks([y + 1 for y in range(len([1]))],
                  labels=[''])
    # ax.set_xlabel('Four separate samples')
    ax.set_ylabel('Mass / g')

plt.show()
