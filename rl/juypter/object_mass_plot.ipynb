# %%
real_masses = [
  93.0,
  119.0,
  187.0,
  224.0,
  200.0,
  159.0,
  180.0,
  232.0,
  478.0,
  455.0,
  217.0,
  598.0,
  335.0,
  491.0,
  565,
  597.0,
  108.0,
  251,
  541.0,
  341.0,
  638.0,
  637.0,
  170.0,
  622.0,
  895.0,
]

ycb_masses = [
  27.0,
  33.0,
  31.0,
  20.0,
  51.0,
  55.0,
  66.0,
  43.0,
  37.0,
  68.0,
  23.0,
  48.0,
  8.0,
  23.0,
  13.0,
  24.0,
  45.0,
  65.0,
]

green_masses = [
  3,
  5,
  9,
  19,
  30,
  47,
  39,
  28,
  34,
  18,
  84,
  64,
  53,
  23,
  40,
  7,
  21,
  18,
  41,
  63,
  12,
  20,
  45,
  75,
  20,
  44,
  12,
  7,
  53,
  106,
]

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = [None for i in range(3)]
axs = [None for i in range(3)]

xsize = 1
ysize = 3

fig[0], axs[0] = plt.subplots(nrows=1, ncols=1, figsize=(xsize, ysize*1.2))
fig[1], axs[1] = plt.subplots(nrows=1, ncols=1, figsize=(xsize, ysize*1.2))
fig[2], axs[2] = plt.subplots(nrows=1, ncols=1, figsize=(xsize, ysize))

# Fixing random state for reproducibility
np.random.seed(19680801)

# generate some random test data
all_data = [np.random.normal(0, std, 100) for std in range(6, 10)]

title = "Mass\nDistribution"

# plot violin plot
axs[0].violinplot(real_masses[:24],
                  showmeans=False,
                  showmedians=True)
axs[0].set_title(title)

# plot violin plot
axs[1].violinplot(ycb_masses,
                  showmeans=False,
                  showmedians=True)
axs[1].set_title(title)

# plot violin plot
axs[2].violinplot(green_masses,
                  showmeans=False,
                  showmedians=True)
axs[2].set_title(title)

# adding horizontal grid lines
for ax in axs:
    ax.yaxis.grid(True)
    ax.set_xticks([y + 1 for y in range(len([1]))],
                  labels=[''])
    # ax.set_xlabel('Four separate samples')
    ax.set_ylabel('Mass / g')

plt.show()
